# %%
execfile('C:/code/external/functions/cosmos/code_splitter.py')

# %%
import os

code_splitter(concatenated_file = 'C:/Cloud/Emory/li, zhongyu - Diabetes Endotypes Project (JV and ZL)/working/cosmos/diabetes_endotypes_cosmos.txt',
output_folder = 'C:/code/external/diabetes_endotypes_cohorts/cosmos')
